# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Любовь это -"

print(generate(model, question))
# Out:
# Любовь это - сказала она, – вот и все понимали, как и всегда бывает на него подарили, и все это представляется в половине двери и просто после портрет просить и просто после портрет при всех подробностях, и в то же время с нею в своем роде войти в сад по себе и подозревал себя подле него и подарок подсудимому и в самом деле спасения своим привели и прочел, – проговорил он вдруг с некоторыми состоянием и представила вас начального показания и все это пристально и необыкновенно всегда после стола не понимает,

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "hello my dear friend"

print(generate(model, question))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 15
#      11 model.to('cpu')
#      12
#      13 question = "hello my dear friend"
#      14
# ---> 15 print(generate(model, question))
#
# File d:\Programs\PythonProjects\Chat\models\gen.py:22, in generate(model, query, len_gen, scale_factor)
#      19 gen_str = query
#      21 model.eval()
# ---> 22 hidden = torch.zeros(model.num_layers, 128, model.hidden_size, device="cpu")
#      23 cell = torch.zeros(model.num_layers, 128, model.hidden_size, device="cpu")
#      25 for char in range(len(query) - 1):
#
# File d:\Programs\PythonProjects\Chat\venv\Lib\site-packages\torch\nn\modules\module.py:1968, in Module.__getattr__(self, name)
#    1966     if name in modules:
#    1967         return modules[name]
# -> 1968 raise AttributeError(
#    1969     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1970 )
#
# AttributeError: 'SeqModel' object has no attribute 'num_layers'
