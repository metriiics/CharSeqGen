# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Любовь это"
scale_factor = 1
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))
# Out:
# Любовь это веришь. Он мне просто совершилось пред тягимимость и сообразить об избу. Так вот в этой самого первых сяда лет вашим об нем зна

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Любовь это"
scale_factor = 10
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))
# Out:
# Любовь это совсем не понимаю, а все это было в самом деле стало быть, всем понимает, что он все простите ли, что я вас не согласится все п

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Любовь это"
scale_factor = 1
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))
# Out:
# Любовь этот таланты и мишую три тысячи лакяем по крайней мере не убирыйте. Стол, опять-таки нельзя. - Ну, господа присяжные, равно теперь вы тогда в ней, то когда она прервал от страдания и всегда другие? Ведь увидим, господа! - и прокурор погибшего, юдо того, что он поставил свой деревни. Мальчики тоже честно, значит. А занимает бы так ей огивне. Мать гостя же нужно, чтоб еще обожертал, несколько снис; свидание все затих, кроме вопросы Мити, которые, опомнился. Он страшно показалось она в другую пронеско

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Любовь это"
scale_factor = 1
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Любовь это"
scale_factor = 1
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Любовь это"
scale_factor = 1
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Любовь это"
scale_factor = 1
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Любовь это"
scale_factor = 1
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))
