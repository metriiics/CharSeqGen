# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "наркотики"

print(generate(model, question))
# Out:
# наркотики и не выследовало. — Какою-то необыкновенною, Дунечку будут все его крылом здесь Бьорине Ивановну, и чего-то место: я, вот, может, они? — Почему? Чего эту минуту: тогда ждать рокову было показывать. Заклаживая грудьюсь тем, что она у него немного вчерашнего здоровье кнута носила как теперь, ее добра, все ты бросился. Я не понимаете, здесь, чувствия, читал в Париж, пошел опять. Когда я веть пораху его с кулачными ручку, тах эпизвалась у него речи видел. Давно протянувшейся на них глуп, как и сама

# %%
loss = torch.tensor(1.44)

torch.exp(loss).item()
# Out:
# 4.220695972442627

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "hello my dear friend"

print(generate(model, question))
# Out:
# hello my dear friend всех прирожденным; я все темных тайны, бы тогда, его в углу, рада, знаешь, что вы сказал в вчества, с тем и уверен и уйду, а может быть. А между тем, деньги, одна будет минуту: конкраску с месту опять не сделавшиеся себя пренеблидели. И не верялись с нам! Да вот это было что-нибудь слаха! Где бы брату-с? Князь весь бы я слишком! - прокружили. Видишь! — Никогда неужто его люблю, и сношенияся, но ударил к гуфьязве! Подишь! Если… вот и засилил, все же знаете хуже другого случае бежжающие мгусок об
