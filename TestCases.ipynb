# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Любовь это"
scale_factor = 1
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))
# Out:
# Любовь это веришь. Он мне просто совершилось пред тягимимость и сообразить об избу. Так вот в этой самого первых сяда лет вашим об нем зна

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Любовь это"
scale_factor = 10
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))
# Out:
# Любовь это совсем не понимаю, а все это было в самом деле стало быть, всем понимает, что он все простите ли, что я вас не согласится все п

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Счастье, это когда я нахожусь в одиночестве самого себя"
scale_factor = 1
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))
# Out:
# Счастье, это когда я нахожусь в одиночестве самого себя. Сама вы ее не ужасно непременно подробному единственно натурально приехать когда поцеловать и мне любезень. – Это ты человек!

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Счастье, это когда я нахожусь в одиночестве самого себя"
scale_factor = 5
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))
# Out:
# Счастье, это когда я нахожусь в одиночестве самого себя подавать на себя подлецом и принимаете в этом случае и не помнить по собственному человеку, чтоб от страха и все это было неско

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Он был один"
scale_factor = 1
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))
# Out:
# Он был один и клеле на него, но даже между тем покажу вшеме приходиться, - продолжал наконец видел. Генерала как-то странно опять решительн

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Он был один"
scale_factor = 5
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))
# Out:
# Он был один из них в нашем преступлении прокурора, который все это произвело в своем роде совершенно необходимым и под конец семейство и пр

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Привет, друг "
scale_factor = 7
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))
# Out:
# Привет, друг мой, с тобой в этом доме и настойчиво проговорил он вдруг с некоторого после приставь об этом по крайней мере не понимает, что о

# %%
import os
import torch
from models.gen import generate

from models.pipeline import SeqModel

import sys
sys.modules['__main__'].SeqModel = SeqModel

model = torch.load(os.path.join("models/weight/", "model.pth"), weights_only=False)
model.to('cpu')

question = "Привет, друг "
scale_factor = 2
length = 128

print(generate(model, question, len_gen=length, scale_factor=scale_factor))
# Out:
# Привет, друг и убийство стало быть, природа вашего половину своей совершенно и простодушно и сердце сорвался от страха и самое сердце собстве
